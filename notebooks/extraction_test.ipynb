# %%
import kaggle

# %%
# lista datasets que você tem acesso
# !kaggle datasets list -s "ecommerce"
# Out:
# ref                                                              title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# saurabhshahane/ecommerce-text-classification                     Ecommerce Text Classification                         8236809  2023-10-09 14:01:29.687000          13510         95  1.0
# cclark/product-item-data                                         eCommerce Item Data                                    140589  2016-08-18 00:32:54.173000          17629        203  0.7058824
# mmohaiminulislam/ecommerce-data-analysis                         ECommerce Data Analysis                              17628279  2024-01-01 02:04:35.787000           7977         62  1.0
# ...
